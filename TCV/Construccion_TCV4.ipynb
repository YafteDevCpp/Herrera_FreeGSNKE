# %%
import numpy as np
import os
import pickle
from freegsnke import build_machine
import matplotlib.pyplot as plt

# %%
if not os.path.exists(f"machine_configs/TCV"):
    os.makedirs(f"machine_configs/TCV")

# Directorio Actual
directorio_actual = os.getcwd()
print(f"Directorio actual: {directorio_actual}")
# Out:
# Directorio actual: /Users/yafte/freegsnke/herrera/TCV

# %% [markdown]
# # Bobinas pasivas

# %%
resistivity_wall = 5.5e-7   # resistivity of material (typically steel)
passive_coils = []

# individual filaments
passive_coils.append({
    "R": 1.0981,
    "Z": 0.6501,
    "dR": 0.0111,
    "dZ": 0.0111,
    "resistivity": resistivity_wall
})

passive_coils.append({
    "R": 1.1139,
    "Z": 0.6319,
    "dR": 0.0111,
    "dZ": 0.0111,
    "resistivity": resistivity_wall
})

passive_coils.append({
    "R": 1.1295,
    "Z": 0.6134,
    "dR": 0.0111,
    "dZ": 0.0111,
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": 1.0981,
    "Z": -0.6501,
    "dR": 0.0111,
    "dZ": 0.0111,
    "resistivity": resistivity_wall
})

passive_coils.append({
    "R": 1.1139,
    "Z": -0.6319,
    "dR": 0.0111,
    "dZ": 0.0111,
    "resistivity": resistivity_wall
})

passive_coils.append({
    "R": 1.1295,
    "Z": -0.6134,
    "dR": 0.0111,
    "dZ": 0.0111,
    "resistivity": resistivity_wall
})

# polygons
passive_coils.append({
    "R": [1.1755, 1.16, 1.16, 1.1755,],  # Sentido antihorario
    "Z": [-0.6044, -0.6044, 0.6044, 0.6044,],  # Sentido antihorario
    "name": 'P1',
    "resistivity": resistivity_wall
})
# P2 - Corregido (orden antihorario)
passive_coils.append({
    "R": [1.1755, 1.1813, 1.16, 1.16,],  # Orden corregido
    "Z": [0.6044, 0.6233, 0.6233, 0.6044,],  # Orden corregido
    "name": 'P2',
    "resistivity": resistivity_wall
})

# P3 - Corregido (orden antihorario)
passive_coils.append({
    "R": [1.1813, 1.1787, 1.16, 1.16,],  # Orden corregido fijarse en el orden
    "Z": [0.6233, 0.643, 0.641, 0.6233,],  # Orden corregido
    "name": 'P3',
    "resistivity": resistivity_wall
})

# P4 - Corregido (orden antihorario)
passive_coils.append({
    "R": [1.1787, 1.1691, 1.1552, 1.16, ],  # Orden corregido fijarse en el orden
    "Z": [0.643, 0.6589, 0.645, 0.641, ],  # Orden corregido
    "name": 'P4',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [1.1691, 1.1552, 1.0061, 1.0132],
    "Z": [0.6589, 0.645, 0.77, 0.7895],
    "name": 'P5',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [1.0061, 1.0132, 0.6493, 0.6473,],
    "Z": [0.77, 0.7895, 0.7895, 0.77,],
    "name": 'P6',
    "resistivity": resistivity_wall
})
# P7 - Corregido (sentido antihorario)
passive_coils.append({
    "R": [0.6493, 0.6473, 0.623, 0.6314,],  # Orden corregido y cerrado
    "Z": [0.77, 0.7895, 0.7843, 0.7661,],  # Orden corregido y cerrado
    "name": 'P7',
    "resistivity": resistivity_wall
})

# P8 - Corregido (sentido antihorario)
passive_coils.append({
    "R": [0.6314, 0.623, 0.6003, 0.6155,],  # Orden corregido y cerrado
    "Z": [0.7661, 0.7843, 0.7671, 0.754,],  # Orden corregido y cerrado
    "name": 'P8',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [0.6155, 0.6003, 0.5894, 0.6071],
    "Z": [0.754, 0.7671, 0.7469, 0.7386],
    "name": 'P9',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [0.5894, 0.6071, 0.6, 0.5834],
    "Z": [0.7469, 0.7386, 0.7207, 0.7295],
    "name": 'P10',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [0.6, 0.5834, 0.5834, 0.6],
    "Z": [0.7207, 0.7295, -0.7295, -0.7207],
    "name": 'P11',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [0.5894, 0.6071, 0.6, 0.5834],
    "Z": [-0.7469, -0.7386, -0.7207, -0.7295],
    "name": 'P12',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [0.6155, 0.6003, 0.5894, 0.6071],
    "Z": [-0.754, -0.7671, -0.7469, -0.7386],
    "name": 'P13',
    "resistivity": resistivity_wall
})
# P14 - Corregido (sentido antihorario)
passive_coils.append({
    "R": [0.6314, 0.623, 0.6003, 0.6155,],  # Orden corregido y cerrado
    "Z": [-0.7661, -0.7843, -0.7671, -0.754,],  # Orden corregido y cerrado
    "name": 'P14',
    "resistivity": resistivity_wall
})
# P15 - Corregido (sentido antihorario)
passive_coils.append({
    "R": [0.6493, 0.6473, 0.623, 0.6314,],  # Orden corregido y cerrado
    "Z": [-0.77, -0.7895, -0.7843, -0.7661,],  # Orden corregido y cerrado
    "name": 'P15',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [1.0061, 1.0132, 0.6493, 0.6473,],
    "Z": [-0.77, -0.7895, -0.7895, -0.77,],
    "name": 'P16',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [1.1691, 1.1552, 1.0061, 1.0132],
    "Z": [-0.6589, -0.645, -0.77, -0.7895],
    "name": 'P17',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [1.1787, 1.1691, 1.1552, 1.16,],  # Orden corregido fijarse en el orden
    "Z": [-0.643, -0.6589, -0.645, -0.641,],  # Orden corregido
    "name": 'P18',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [1.1813, 1.1787, 1.16, 1.16, ],  # Orden corregido fijarse en el orden
    "Z": [-0.6233, -0.643, -0.641, -0.6233, ],  # Orden corregido
    "name": 'P19',
    "resistivity": resistivity_wall
})
passive_coils.append({
    "R": [1.1755, 1.1813, 1.16, 1.16,],  # Orden corregido
    "Z": [-0.6044, -0.6233, -0.6233, -0.6044,],  # Orden corregido
    "name": 'P20',
    "resistivity": resistivity_wall
})

# %%
with open (f"machine_configs/TCV/passive_coils.pickle", "wb") as f:
    pickle.dump(passive_coils, f)

# %% [markdown]
# # Paredes

# %%
r_wall= [1.16, 1.16, 1.16, 1.16, 1.0061, 0.88, 0.77, 0.6493, 0.6314, 0.6155, 0.6071, 0.6, 0.6, 0.6, 0.6, 0.6
    ]
z_wall = [0, 0.2448, 0.4743, 0.641, 0.77, 0.77, 0.77, 0.77, 0.7661, 0.754, 0.7386, 0.7207, 0.641, 0.4743, 0.2454, 0
    ]

r_wall = r_wall + r_wall[::-1]
z_wall = z_wall + [-z for z in z_wall[::-1]]

wall = []
for r, z in zip(r_wall, z_wall):
    wall.append({"R": r, "Z": z})

with open(f"machine_configs/TCV/wall.pickle", "wb") as f:
   pickle.dump(wall, f)

# %%
r_wall_reflejado = r_wall

# Imprimir en una sola línea separados por comas
print(', '.join(map(str, r_wall_reflejado)))
# Out:
# 1.16, 1.16, 1.16, 1.16, 1.0061, 0.88, 0.77, 0.6493, 0.6314, 0.6155, 0.6071, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6071, 0.6155, 0.6314, 0.6493, 0.77, 0.88, 1.0061, 1.16, 1.16, 1.16, 1.16

# %%
r_wall_reflejado_negativo = r_wall[::-1]

# Imprimir en una sola línea separados por comas
print(', '.join(map(str, r_wall_reflejado_negativo)))
# Out:
# 1.16, 1.16, 1.16, 1.16, 1.0061, 0.88, 0.77, 0.6493, 0.6314, 0.6155, 0.6071, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6071, 0.6155, 0.6314, 0.6493, 0.77, 0.88, 1.0061, 1.16, 1.16, 1.16, 1.16

# %%
z_wall_reflejado = [-1 * z for z in z_wall[::-1]]

# Mostrar los datos reflejados
print(', '.join(map(str, z_wall_reflejado)))
# Out:
# 0, 0.2448, 0.4743, 0.641, 0.77, 0.77, 0.77, 0.77, 0.7661, 0.754, 0.7386, 0.7207, 0.641, 0.4743, 0.2454, 0, 0, -0.2454, -0.4743, -0.641, -0.7207, -0.7386, -0.754, -0.7661, -0.77, -0.77, -0.77, -0.77, -0.641, -0.4743, -0.2448, 0

# %%
a=[0.7777, 0.7777, 0.7777,
          0.7575, 0.7575, 0.7575,
          0.7373, 0.7373, 0.7373,
          0.7171, 0.7171, 0.7171,
          0.6969, 0.6969, 0.6969,
          0.6767, 0.6767, 0.6767,
          0.6565, 0.6565, 0.6565,
          0.6363, 0.6363, 0.6363,
          0.6161, 0.6161, 0.6161,
          0.5959, 0.5959, 0.5959,
          0.5757, 0.5757, 0.5757,
          0.5555, 0.5555, 0.5555,
          0.5353, 0.5353, 0.5353,
          0.5151, 0.5151, 0.5151,
          0.4949, 0.4949, 0.4949,
          0.4747, 0.4747, 0.4747,
          0.4545, 0.4545, 0.4545,
          0.4343, 0.4343, 0.4343,
          0.4141, 0.4141, 0.4141,
          0.3939, 0.3939, 0.3939,
          0.3737, 0.3737, 0.3737,
          0.3535, 0.3535, 0.3535,
          0.3333, 0.3333, 0.3333,
          0.3131, 0.3131, 0.3131,
          0.2929, 0.2929, 0.2929,
          0.2727, 0.2727, 0.2727,
          0.2525, 0.2525, 0.2525,
          0.2323, 0.2323, 0.2323,
          0.2121, 0.2121, 0.2121,
          0.1919, 0.1919, 0.1919,
          0.1717, 0.1717, 0.1717,
          0.1515, 0.1515, 0.1515,
          0.1313, 0.1313, 0.1313,
          0.1111, 0.1111, 0.1111,
          0.0909, 0.0909, 0.0909,
          0.0707, 0.0707, 0.0707,
          0.0505, 0.0505, 0.0505,
          0.0303, 0.0303, 0.0303,
          0.0101, 0.0101, 0.0101,]

a_reflejado = [-1 * a for a in a[::-1]]

# Mostrar los datos reflejados
print(', '.join(map(str, a_reflejado)))
# Out:
# -0.0101, -0.0101, -0.0101, -0.0303, -0.0303, -0.0303, -0.0505, -0.0505, -0.0505, -0.0707, -0.0707, -0.0707, -0.0909, -0.0909, -0.0909, -0.1111, -0.1111, -0.1111, -0.1313, -0.1313, -0.1313, -0.1515, -0.1515, -0.1515, -0.1717, -0.1717, -0.1717, -0.1919, -0.1919, -0.1919, -0.2121, -0.2121, -0.2121, -0.2323, -0.2323, -0.2323, -0.2525, -0.2525, -0.2525, -0.2727, -0.2727, -0.2727, -0.2929, -0.2929, -0.2929, -0.3131, -0.3131, -0.3131, -0.3333, -0.3333, -0.3333, -0.3535, -0.3535, -0.3535, -0.3737, -0.3737, -0.3737, -0.3939, -0.3939, -0.3939, -0.4141, -0.4141, -0.4141, -0.4343, -0.4343, -0.4343, -0.4545, -0.4545, -0.4545, -0.4747, -0.4747, -0.4747, -0.4949, -0.4949, -0.4949, -0.5151, -0.5151, -0.5151, -0.5353, -0.5353, -0.5353, -0.5555, -0.5555, -0.5555, -0.5757, -0.5757, -0.5757, -0.5959, -0.5959, -0.5959, -0.6161, -0.6161, -0.6161, -0.6363, -0.6363, -0.6363, -0.6565, -0.6565, -0.6565, -0.6767, -0.6767, -0.6767, -0.6969, -0.6969, -0.6969, -0.7171, -0.7171, -0.7171, -0.7373, -0.7373, -0.7373,
# ...

# %%
path = f"machine_configs/TCV/wall.pickle"

with open(path, 'rb') as f:
    wall_data = pickle.load(f)

print(type (wall_data))
print(len(wall_data))
for i, item in enumerate(wall_data[:33]):  # Muestra los primeros 5 elementos
    print(f"\nElemento {i}:")
    print(f"Tipo: {type(item)}")
    print(item)
# Out:
# <class 'list'>
# 32
#
# Elemento 0:
# Tipo: <class 'dict'>
# {'R': 1.16, 'Z': 0}
#
# Elemento 1:
# Tipo: <class 'dict'>
# {'R': 1.16, 'Z': 0.2448}
#
# Elemento 2:
# Tipo: <class 'dict'>
# {'R': 1.16, 'Z': 0.4743}
#
# Elemento 3:
# Tipo: <class 'dict'>
# {'R': 1.16, 'Z': 0.641}
#
# Elemento 4:
# Tipo: <class 'dict'>
# {'R': 1.0061, 'Z': 0.77}
#
# Elemento 5:
# Tipo: <class 'dict'>
# {'R': 0.88, 'Z': 0.77}
#
# Elemento 6:
# Tipo: <class 'dict'>
# {'R': 0.77, 'Z': 0.77}
#
# Elemento 7:
# Tipo: <class 'dict'>
# {'R': 0.6493, 'Z': 0.77}
#
# Elemento 8:
# Tipo: <class 'dict'>
# {'R': 0.6314, 'Z': 0.7661}
#
# Elemento 9:
# Tipo: <class 'dict'>
# {'R': 0.6155, 'Z': 0.754}
#
# Elemento 10:
# Tipo: <class 'dict'>
# {'R': 0.6071, 'Z': 0.7386}
#
# Elemento 11:
# Tipo: <class 'dict'>
# {'R': 0.6, 'Z': 0.7207}
#
# Elemento 12:
# Tipo: <class 'dict'>
# {'R': 0.6, 'Z': 0.641}
#
# Elemento 13:
# Tipo: <class 'dict'>
# {'R': 0.6, 'Z': 0.4743}
#
# Elemento 14:
# Tipo: <class 'dict'>
# ...

# %%
print(wall_data)
# Out:
# [{'R': 1.16, 'Z': 0}, {'R': 1.16, 'Z': 0.2448}, {'R': 1.16, 'Z': 0.4743}, {'R': 1.16, 'Z': 0.641}, {'R': 1.0061, 'Z': 0.77}, {'R': 0.88, 'Z': 0.77}, {'R': 0.77, 'Z': 0.77}, {'R': 0.6493, 'Z': 0.77}, {'R': 0.6314, 'Z': 0.7661}, {'R': 0.6155, 'Z': 0.754}, {'R': 0.6071, 'Z': 0.7386}, {'R': 0.6, 'Z': 0.7207}, {'R': 0.6, 'Z': 0.641}, {'R': 0.6, 'Z': 0.4743}, {'R': 0.6, 'Z': 0.2454}, {'R': 0.6, 'Z': 0}, {'R': 0.6, 'Z': 0}, {'R': 0.6, 'Z': -0.2454}, {'R': 0.6, 'Z': -0.4743}, {'R': 0.6, 'Z': -0.641}, {'R': 0.6, 'Z': -0.7207}, {'R': 0.6071, 'Z': -0.7386}, {'R': 0.6155, 'Z': -0.754}, {'R': 0.6314, 'Z': -0.7661}, {'R': 0.6493, 'Z': -0.77}, {'R': 0.77, 'Z': -0.77}, {'R': 0.88, 'Z': -0.77}, {'R': 1.0061, 'Z': -0.77}, {'R': 1.16, 'Z': -0.641}, {'R': 1.16, 'Z': -0.4743}, {'R': 1.16, 'Z': -0.2448}, {'R': 1.16, 'Z': 0}]

# %%
import matplotlib.pyplot as plt

# Extraer coordenadas R y Z del pickle
R = [p["R"] for p in wall]
Z = [p["Z"] for p in wall]

plt.figure(figsize=(7, 9))
plt.plot(R, Z, '-k', linewidth=1.5, label='Contorno pared')

# Etiquetar cada punto con su índice
for i, (r, z) in enumerate(zip(R, Z)):
    plt.plot(r, z, 'ro', markersize=2)
    plt.text(r, z, str(i), fontsize=7, ha='center', va='bottom', rotation=30)

plt.xlabel('Major Radius [m]')
plt.ylabel('Height Z [m]')
plt.title('Numeración de puntos en la pared MAST-U')
plt.axis('equal')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bobinas activas

# %%
eta_copper = 1.55e-8  # resistivity in Ohm*m
active_coils = {}

# %%
active_coils["F8"] = {}

active_coils["F8"]= {
    "R": [1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          ],
    "Z": [0.7982, 0.7982, 0.7982, 0.7982, 0.7982,
          0.778, 0.778, 0.778, 0.778, 0.778,
          0.7578, 0.7578, 0.7578, 0.7578, 0.7578,
          0.7376, 0.7376, 0.7376, 0.7376, 0.7376,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["F1"] = {}
# Populate with the P1_lower coil information
active_coils["F1"] = {
    "R": [1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          ],
    "Z": [-1*z for z in [0.7982, 0.7982, 0.7982, 0.7982, 0.7982,
                         0.778, 0.778, 0.778, 0.778, 0.778,
                         0.7578, 0.7578, 0.7578, 0.7578, 0.7578,
                         0.7376, 0.7376, 0.7376, 0.7376, 0.7376,
                         ]],
    # note the lower coil has opposite mirrored z-coords compared to upper
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,                             # note polarity is 1, so it will have same current as upper coil
    "multiplier": 1,
}

active_coils["F7"] = {}

active_coils["F7"] = {
    "R": [1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          ],
    "Z": [0.6376, 0.6376, 0.6376, 0.6376, 0.6376,
          0.6174, 0.6174, 0.6174, 0.6174, 0.6174,
          0.5972, 0.5972, 0.5972, 0.5972, 0.5972,
          0.577, 0.577, 0.577, 0.577, 0.577,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["F2"] = {}
active_coils["F2"] = {
    "R": [1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          ],
    "Z": [-1*z for z in [0.6376, 0.6376, 0.6376, 0.6376, 0.6376,
                         0.6174, 0.6174, 0.6174, 0.6174, 0.6174,
                         0.5972, 0.5972, 0.5972, 0.5972, 0.5972,
                         0.577, 0.577, 0.577, 0.577, 0.577,
                        ]],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

active_coils["F6"] = {}

active_coils["F6"] = {
    "R": [1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          ],
    "Z": [0.3393, 0.3393, 0.3393, 0.3393, 0.3393,
          0.3191, 0.3191, 0.3191, 0.3191, 0.3191,
          0.2989, 0.2989, 0.2989, 0.2989, 0.2989,
          0.2787, 0.2787, 0.2787, 0.2787, 0.2787,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["F3"] = {}
active_coils["F3"] = {
    "R": [1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          ],
    "Z": [-1*z for z in [0.3393, 0.3393, 0.3393, 0.3393, 0.3393,
                         0.3191, 0.3191, 0.3191, 0.3191, 0.3191,
                         0.2989, 0.2989, 0.2989, 0.2989, 0.2989,
                         0.2787, 0.2787, 0.2787, 0.2787, 0.2787,
                        ]],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

active_coils["F5"] = {}

active_coils["F5"] = {
    "R": [1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          ],
    "Z": [0.1787, 0.1787, 0.1787, 0.1787, 0.1787,
          0.1585, 0.1585, 0.1585, 0.1585, 0.1585,
          0.1383, 0.1383, 0.1383, 0.1383, 0.1383,
          0.1181, 0.1181, 0.1181, 0.1181, 0.1181,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["F4"] = {}
active_coils["F4"] = {
    "R": [1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          1.2611, 1.2873, 1.3135, 1.3397, 1.3659,
          ],
    "Z": [-1*z for z in [0.1787, 0.1787, 0.1787, 0.1787, 0.1787,
                         0.1585, 0.1585, 0.1585, 0.1585, 0.1585,
                         0.1383, 0.1383, 0.1383, 0.1383, 0.1383,
                         0.1181, 0.1181, 0.1181, 0.1181, 0.1181,
                        ]],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

active_coils["D2"] = {}

active_coils["D2"] = {
    "R": [1.1495, 1.1757, 1.2019,
          1.1495, 1.1757, 1.2019,
          1.1495, 1.1757, 1.2019,
          1.1495, 1.1757, 1.2019,
          1.1495, 1.1757, 1.2019,
           ],
    "Z": [1.202, 1.202, 1.202,
          1.1818, 1.1818, 1.1818,
          1.1616, 1.1616, 1.1616,
          1.1414, 1.1414, 1.1414,
          1.1212, 1.1212, 1.1212,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["D1"] = {}
active_coils["D1"] = {
    "R": [1.1495, 1.1757, 1.2019,
          1.1495, 1.1757, 1.2019,
          1.1495, 1.1757, 1.2019,
          1.1495, 1.1757, 1.2019,
          1.1495, 1.1757, 1.2019,
           ],
    "Z": [-1*z for z in [1.202, 1.202, 1.202,
                         1.1818, 1.1818, 1.1818,
                         1.1616, 1.1616, 1.1616,
                         1.1414, 1.1414, 1.1414,
                         1.1212, 1.1212, 1.1212,
                        ]],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

active_coils["C2"] = {}

active_coils["C2"] = {
    "R": [0.5939, 0.6201, 0.6463,
          0.5939, 0.6201, 0.6463,
          0.5939, 0.6201, 0.6463,
          0.5939, 0.6201, 0.6463,
          0.5939, 0.6201, 0.6463,
          0.5939, 0.6201, 0.6463,
         ],
    "Z": [1.1582, 1.1582, 1.1582,
          1.138, 1.138, 1.138,
          1.1178, 1.1178, 1.1178,
          1.0976, 1.0976, 1.0976,
          1.0774, 1.0774, 1.0774,
          1.0572, 1.0572, 1.0572,
         ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["C1"] = {}
active_coils["C1"] = {
    "R": [0.5939, 0.6201, 0.6463,
          0.5939, 0.6201, 0.6463,
          0.5939, 0.6201, 0.6463,
          0.5939, 0.6201, 0.6463,
          0.5939, 0.6201, 0.6463,
          0.5939, 0.6201, 0.6463,
          ],
    "Z": [-1*z for z in [1.1582, 1.1582, 1.1582,
                         1.138, 1.138, 1.138,
                         1.1178, 1.1178, 1.1178,
                         1.0976, 1.0976, 1.0976,
                         1.0774, 1.0774, 1.0774,
                         1.0572, 1.0572, 1.0572,
                         ]],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

active_coils["B2"] = {}

active_coils["B2"] = {
    "R": [0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          ],
    "Z": [1.0158, 1.0158, 1.0158, 1.0158,
          0.9956, 0.9956, 0.9956, 0.9956,
          0.9754, 0.9754, 0.9754, 0.9754,
          0.9552, 0.9552, 0.9552, 0.9552,
          0.935, 0.935, 0.935, 0.935,
          0.9148, 0.9148, 0.9148, 0.9148,
          0.8946, 0.8946, 0.8946, 0.8946,
          0.8744, 0.8744, 0.8744, 0.8744,
          0.8542, 0.8542, 0.8542, 0.8542,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["B1"] = {}
active_coils["B1"] = {
    "R": [0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          0.407, 0.4332, 0.4594, 0.4856,
          ],
    "Z": [-1*z for z in [1.0158, 1.0158, 1.0158, 1.0158,
                         0.9956, 0.9956, 0.9956, 0.9956,
                         0.9754, 0.9754, 0.9754, 0.9754,
                         0.9552, 0.9552, 0.9552, 0.9552,
                         0.935, 0.935, 0.935, 0.935,
                         0.9148, 0.9148, 0.9148, 0.9148,
                         0.8946, 0.8946, 0.8946, 0.8946,
                         0.8744, 0.8744, 0.8744, 0.8744,
                         0.8542, 0.8542, 0.8542, 0.8542,
                          ]],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

active_coils["E8"] = {}

active_coils["E8"] = {
    "R": [0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          ],
    "Z": [0.7799, 0.7799,
          0.7597, 0.7597,
          0.7395, 0.7395,
          0.7193, 0.7193,
          0.6991, 0.6991,
          0.6789, 0.6789,
          0.6587, 0.6587,
          0.6385, 0.6385,
          0.6183, 0.6183,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["E1"] = {}
active_coils["E1"] = {
    "R": [0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          ],
    "Z": [-1*z for z in [0.7799, 0.7799,
                         0.7597, 0.7597,
                         0.7395, 0.7395,
                         0.7193, 0.7193,
                         0.6991, 0.6991,
                         0.6789, 0.6789,
                         0.6587, 0.6587,
                         0.6385, 0.6385,
                         0.6183, 0.6183,
                         ]],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

active_coils["E7"] = {}

active_coils["E7"] = {
    "R": [0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          ],
    "Z": [0.5799, 0.5799,
          0.5597, 0.5597,
          0.5395, 0.5395,
          0.5193, 0.5193,
          0.4991, 0.4991,
          0.4789, 0.4789,
          0.4587, 0.4587,
          0.4385, 0.4385,
          0.4183, 0.4183,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["E2"] = {}
active_coils["E2"] = {
    "R": [0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          ],
    "Z": [-1*z for z in [0.5799, 0.5799,
                         0.5597, 0.5597,
                         0.5395, 0.5395,
                         0.5193, 0.5193,
                         0.4991, 0.4991,
                         0.4789, 0.4789,
                         0.4587, 0.4587,
                         0.4385, 0.4385,
                         0.4183, 0.4183,
                          ]],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

active_coils["E6"] = {}

active_coils["E6"] = {
    "R": [0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          ],
    "Z": [0.3799, 0.3799,
          0.3597, 0.3597,
          0.3395, 0.3395,
          0.3193, 0.3193,
          0.2991, 0.2991,
          0.2789, 0.2789,
          0.2587, 0.2587,
          0.2385, 0.2385,
          0.2183, 0.2183,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["E3"] = {}
active_coils["E3"] = {
    "R": [0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          ],
    "Z": [-1*z for z in [0.3799, 0.3799,
                         0.3597, 0.3597,
                         0.3395, 0.3395,
                         0.3193, 0.3193,
                         0.2991, 0.2991,
                         0.2789, 0.2789,
                         0.2587, 0.2587,
                         0.2385, 0.2385,
                         0.2183, 0.2183,
                          ]],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

active_coils["E5"] = {}

active_coils["E5"] = {
    "R": [0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          ],
    "Z": [0.1799, 0.1799,
          0.1597, 0.1597,
          0.1395, 0.1395,
          0.1193, 0.1193,
          0.0991, 0.0991,
          0.0789, 0.0789,
          0.0587, 0.0587,
          0.0385, 0.0385,
          0.0183, 0.0183,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["E4"] = {}
active_coils["E4"] = {
    "R": [0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          0.4933, 0.5195,
          ],
    "Z": [-1*z for z in [0.1799, 0.1799,
                         0.1597, 0.1597,
                         0.1395, 0.1395,
                         0.1193, 0.1193,
                         0.0991, 0.0991,
                         0.0789, 0.0789,
                         0.0587, 0.0587,
                         0.0385, 0.0385,
                         0.0183, 0.0183,
                        ]],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["T1"] = {}

active_coils["T1"] = {
    "R": [1.5529,
          1.5529,
          1.5529,
          1.5529,
          1.5529,
          1.5529,
          1.5529,
          ],
    "Z": [-0.7175,
          -0.7377,
          -0.7579,
          -0.7781,
          -0.7983,
          -0.8185,
          -0.8387,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["T2"] = {}

active_coils["T2"] = {
    "R": [1.7155,
          1.7155,
          1.7155,
          1.7155,
          1.7155,
          1.7155,
          1.7155,
          ],
    "Z": [-0.7175,
          -0.7377,
          -0.7579,
          -0.7781,
          -0.7983,
          -0.8185,
          -0.8387,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}
active_coils["T3"] = {}

active_coils["T3"] = {
    "R": [1.7536,
          1.7536,
          1.7536,
          1.7536,
          1.7536,
          1.7536,
          1.7536,
          ],
    "Z": [-0.7175,
          -0.7377,
          -0.7579,
          -0.7781,
          -0.7983,
          -0.8185,
          -0.8387,
          ],
    "dR": 0.0262,
    "dZ": 0.0202,
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

# Valores R fijos (5 puntos)
R_vals = [0.3979, 0.4106, 0.4234, 0.4362, 0.4489]

# Valores Z optimizados (40 puntos)
Z_vals = [
    0.7702, 0.7307, 0.6918, 0.6523, 0.6128, 0.5732, 0.5337, 0.4942,
    0.4540, 0.4144, 0.3756, 0.3360, 0.2965, 0.2570, 0.2174, 0.1779,
    0.1377, 0.0982, 0.0593, 0.0198, -0.0198, -0.0593, -0.0982, -0.1377,
    -0.1779, -0.2174, -0.2570, -0.2965, -0.3360, -0.3756, -0.4144, -0.4540,
    -0.4942, -0.5337, -0.5732, -0.6128, -0.6523, -0.6918, -0.7307, -0.7702
]

# Crear malla completa (5×40 = 200 elementos)
R_full = []
Z_full = []

for z in Z_vals:
    for r in R_vals:
        R_full.append(r)
        Z_full.append(z)

active_coils["Solenoid"] = {
    "R": R_full,
    "Z": Z_full,
    "dR": 0.0128,  # Ancho fijo
    "dZ": 0.0382,  # Ancho fijo
    "resistivity": eta_copper,
    "polarity": 1,
    "multiplier": 1,
}

# %%
with open(f"machine_configs/TCV/active_coils4.pickle", "wb") as f:
   pickle.dump(active_coils, f)

# %% [markdown]
# # Limiter

# %%
r_limiter =[1.1364, 1.1364, 1.1364, 1.1364, 0.9723, 0.88, 0.6706, 0.6222, 0.6222, 0.6222, 0.6222, 0.6222]
z_limiter =[0, 0.1585, 0.3758, 0.5537, 0.7481, 0.7481, 0.7481, 0.7012, 0.5537, 0.3758, 0.1585, 0]

r_limiter = r_limiter + r_limiter[::-1]
z_limiter = z_limiter + [-z for z in z_limiter[::-1]]

limiter = []
for r, z in zip(r_limiter, z_limiter):
    limiter.append({"R": r, "Z": z})

# %%
with open(f"machine_configs/TCV/limiter.pickle", "wb") as f:
   pickle.dump(limiter, f)

# %% [markdown]
# # Pruebas Magnéticas

# %%
# create list of flux loop dictionaries
flux_loops = []
flux_loops.append({'name': 'fl_u_01', 'position': np.array([1.1755, 0])})
flux_loops.append({'name': 'fl_u_02', 'position':np.array([1.1755, 0.1142])})
flux_loops.append({'name': 'fl_u_03', 'position':np.array([1.1755, 0.229])})
flux_loops.append({'name': 'fl_u_04', 'position':np.array([1.1755, 0.3445])})
flux_loops.append({'name': 'fl_u_05', 'position':np.array([1.1755, 0.4593])})
flux_loops.append({'name': 'fl_u_06', 'position':np.array([1.1755, 0.5733])})
flux_loops.append({'name': 'fl_u_07', 'position':np.array([1.1347, 0.6877])})
flux_loops.append({'name': 'fl_u_08', 'position':np.array([1.058, 0.752])})
flux_loops.append({'name': 'fl_u_09', 'position':np.array([0.9815, 0.7895])})
flux_loops.append({'name': 'fl_u_10', 'position':np.array([0.8861, 0.7895])})
flux_loops.append({'name': 'fl_u_11', 'position':np.array([0.7906, 0.7895])})
flux_loops.append({'name': 'fl_u_12', 'position':np.array([0.6951, 0.7895])})
flux_loops.append({'name': 'fl_u_13', 'position':np.array([0.6003, 0.7671])})
flux_loops.append({'name': 'fl_u_14', 'position':np.array([0.5834, 0.6919])})
flux_loops.append({'name': 'fl_u_15', 'position':np.array([0.5834, 0.5767])})
flux_loops.append({'name': 'fl_u_16', 'position':np.array([0.5834, 0.4615])})
flux_loops.append({'name': 'fl_u_17', 'position':np.array([0.5834, 0.3462])})
flux_loops.append({'name': 'fl_u_18', 'position':np.array([0.5834, 0.2307])})
flux_loops.append({'name': 'fl_u_19', 'position':np.array([0.5834, 0.1155])})
flux_loops.append({'name': 'fl_u_20', 'position':np.array([0.5834, 0])})
flux_loops.append({'name': 'fl_u_21', 'position':np.array([1.2488, 0.1476])})
flux_loops.append({'name': 'fl_u_22', 'position':np.array([1.2488, 0.3101])})
flux_loops.append({'name': 'fl_u_23', 'position':np.array([1.2488, 0.6065])})
flux_loops.append({'name': 'fl_u_24', 'position':np.array([1.2488, 0.769])})
flux_loops.append({'name': 'fl_u_25', 'position':np.array([1.143, 1.1673])})
flux_loops.append({'name': 'fl_u_26', 'position':np.array([0.6551, 1.1082])})
flux_loops.append({'name': 'fl_u_27', 'position':np.array([0.4463, 1.0733])})
flux_loops.append({'name': 'fl_u_28', 'position':np.array([0.5013, 0.9339])})
flux_loops.append({'name': 'fl_u_29', 'position':np.array([0.5316, 0.7024])})
flux_loops.append({'name': 'fl_u_30', 'position':np.array([0.5316, 0.5017])})
flux_loops.append({'name': 'fl_u_31', 'position':np.array([0.5316, 0.301])})
flux_loops.append({'name': 'fl_u_32', 'position':np.array([0.5316, 0.1003])})
flux_loops.append({'name': 'fl_l_02', 'position':np.array([1.1755, -0.1142])})
flux_loops.append({'name': 'fl_l_03', 'position':np.array([1.1755, -0.229])})
flux_loops.append({'name': 'fl_l_04', 'position':np.array([1.1755, -0.3445])})
flux_loops.append({'name': 'fl_l_05', 'position':np.array([1.1755, -0.4593])})
flux_loops.append({'name': 'fl_l_06', 'position':np.array([1.1755, -0.5733])})
flux_loops.append({'name': 'fl_l_07', 'position':np.array([1.1347, -0.6877])})
flux_loops.append({'name': 'fl_l_08', 'position':np.array([1.058, -0.752])})
flux_loops.append({'name': 'fl_l_09', 'position':np.array([0.9815, -0.7895])})
flux_loops.append({'name': 'fl_l_10', 'position':np.array([0.8861, -0.7895])})
flux_loops.append({'name': 'fl_l_11', 'position':np.array([0.7906, -0.7895])})
flux_loops.append({'name': 'fl_l_12', 'position':np.array([0.6951, -0.7895])})
flux_loops.append({'name': 'fl_l_13', 'position':np.array([0.6003, -0.7671])})
flux_loops.append({'name': 'fl_l_14', 'position':np.array([0.5834, -0.6919])})
flux_loops.append({'name': 'fl_l_15', 'position':np.array([0.5834, -0.5767])})
flux_loops.append({'name': 'fl_l_16', 'position':np.array([0.5834, -0.4615])})
flux_loops.append({'name': 'fl_l_17', 'position':np.array([0.5834, -0.3462])})
flux_loops.append({'name': 'fl_l_18', 'position':np.array([0.5834, -0.2307])})
flux_loops.append({'name': 'fl_l_19', 'position':np.array([0.5834, -0.1155])})
flux_loops.append({'name': 'fl_l_21', 'position':np.array([1.2488, -0.1476])})
flux_loops.append({'name': 'fl_l_22', 'position':np.array([1.2488, -0.3101])})
flux_loops.append({'name': 'fl_l_23', 'position':np.array([1.2488, -0.6065])})
flux_loops.append({'name': 'fl_l_24', 'position':np.array([1.2488, -0.769])})
flux_loops.append({'name': 'fl_l_25', 'position':np.array([1.143, -1.1673])})
flux_loops.append({'name': 'fl_l_26', 'position':np.array([0.6551, -1.1082])})
flux_loops.append({'name': 'fl_l_27', 'position':np.array([0.4463, -1.0733])})
flux_loops.append({'name': 'fl_l_28', 'position':np.array([0.5013, -0.9339])})
flux_loops.append({'name': 'fl_l_29', 'position':np.array([0.5316, -0.7024])})
flux_loops.append({'name': 'fl_l_30', 'position':np.array([0.5316, -0.5017])})
flux_loops.append({'name': 'fl_l_31', 'position':np.array([0.5316, -0.301])})
flux_loops.append({'name': 'fl_l_32', 'position':np.array([0.5316, -0.1003])})

# create list of pickup coil dictionaries
pickup_coils = []

# create magnetic probes dictionary
magnetic_probes = {'flux_loops': flux_loops, 'pickups': pickup_coils}

# save as pickle file
with open(f"machine_configs/TCV/magnetic_probes.pickle", "wb") as f:
   pickle.dump(magnetic_probes, f)

# %% [markdown]
# # Construcción

# %%
directorio_actual
# Out:
# '/Users/yafte/freegsnke/herrera/TCV'

# %%
passive_coils_path = f"{directorio_actual}/machine_configs/TCV/passive_coils.pickle"
passive_coils_path
# Out:
# '/Users/yafte/freegsnke/herrera/TCV/machine_configs/TCV/passive_coils.pickle'

# %%
tokamak=build_machine.tokamak(
    passive_coils_path = f"{directorio_actual}/machine_configs/TCV/passive_coils.pickle",
    active_coils_path=f"{directorio_actual}/machine_configs/TCV/active_coils4.pickle",
    limiter_path=f"{directorio_actual}/machine_configs/TCV/limiter.pickle",
    wall_path=f"{directorio_actual}/machine_configs/TCV/wall.pickle",
    magnetic_probe_path=f"{directorio_actual}/machine_configs/TCV/magnetic_probes.pickle",
)
    # plot the resulting equilbria
fig1, ax1 = plt.subplots(1, 1, figsize=(4, 8), dpi=90)
plt.tight_layout()

tokamak.plot(axis=ax1, show=False)
ax1.plot(tokamak.limiter.R, tokamak.limiter.Z, color='k', linewidth=1.2, linestyle="--")
ax1.plot(tokamak.wall.R, tokamak.wall.Z, color='k', linewidth=1.2, linestyle="-")

ax1.grid(alpha=1.0)
ax1.set_aspect('equal')
ax1.set_xlim(0.3, 1.85)
ax1.set_ylim(-1.3, 1.3)
ax1.set_xlabel(r'Major radius, $R$ [m]')
ax1.set_ylabel(r'Height, $Z$ [m]')
# Out:
# Active coils --> built from pickle file.
# Passive structures --> built from pickle file.
# Limiter --> built from pickle file.
# Wall --> built from pickle file.
# Magnetic probes --> built from pickle file.
# Resistance (R) and inductance (M) matrices --> built using actives (and passives if present).
# Tokamak built.
# Text(11.25, 0.5, 'Height, $Z$ [m]')
